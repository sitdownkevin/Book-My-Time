# %%
import icalendar
from enum import Enum, auto
from zoneinfo import ZoneInfo
from datetime import (
    datetime, date,
    timedelta, timezone
)

utc_8 = ZoneInfo('Etc/GMT+8')

# %%
ics_file_path = r'./data/test/basic.ics'

with open(ics_file_path, 'r', encoding='utf-8') as f:
    calendar = icalendar.Calendar.from_ical(f.read())

# %%
class StEventType:
    REGULAR = 'Regular'
    ALL_DAY = 'All day'
    FREE = 'Free'
    BOOKED = 'Not free'


class StEvent:
    def __init__(self, event_type: StEventType, t_start: date | datetime, t_end: date | datetime, summary: str,):
        self.event_type = event_type
        self.t_start = t_start if event_type == StEventType.ALL_DAY else self._ensure_datetime(t_start)
        self.t_end = t_end if event_type == StEventType.ALL_DAY else self._ensure_datetime(t_end)
        self.summary = str(summary)

        self.index = self._ensure_datetime(self.t_start)
        

    def __str__(self):
        t_start_str = self.t_start if self.event_type == StEventType.ALL_DAY else self.t_start.strftime('%Y-%m-%d %H:%M')
        t_end_str = self.t_end if self.event_type == StEventType.ALL_DAY else self.t_end.strftime('%Y-%m-%d %H:%M')

        return f"Event Type: {self.event_type}, Start: {t_start_str}, End: {t_end_str}, Summary: {self.summary}"


    def jsonify(self):
        if self.event_type == 'All day':
            return {
                'type': self.event_type,
                't_start': {
                    'year': self.t_start.year,
                    'month': self.t_start.month,
                    'date': self.t_start.day,
                },
                't_end': {
                    'year': self.t_end.year,
                    'month': self.t_end.month,
                    'date': self.t_end.day,
                },
                'summary': self.summary,
            }
        else:
            return {
                'type': self.event_type,
                't_start': self.t_start.timestamp(),
                't_end': self.t_end.timestamp(),
                'summary': self.summary,
            }
    
        
    @staticmethod
    def _ensure_datetime(dt):
        """Make sure the dt is in type of datetime"""        
        if isinstance(dt, datetime):
            dt = dt.replace(tzinfo=None)
        elif isinstance(dt, date):
            dt = datetime(dt.year, dt.month, dt.day)
            
        return dt

# %%
def get_events_from_calendar(calendar):
    """"""
    events = []

    for event in calendar.walk('VEVENT'):
        dtstart = event.get('dtstart').dt
        dtend = event.get('dtend').dt

        if isinstance(dtstart, date) and isinstance(dtend, date) and not (isinstance(dtstart, datetime)) and not (isinstance(dtend, datetime)):
            # 全天事件
            # print('')
            # print(dtstart, dtend, event.get('summary'))
            events.append(
                StEvent(StEventType.ALL_DAY, dtstart, dtend, event.get('summary'))
            )

        elif isinstance(dtstart, datetime) and isinstance(dtend, datetime):
            # 常规事件
            # print('')
            # print(dtstart.astimezone(utc_8), dtend.astimezone(utc_8), event.get('summary'))
            events.append(
                StEvent(StEventType.REGULAR, dtstart, dtend, event.get('summary'))
            )

    events = sorted(events, key=lambda event: event.index)
    
    return events


def find_events_in_range(t_start: datetime, t_end: datetime):
    pass

# %%
class StCalendar:
    def __init__(self, events=[]):
        self.events = events
        self.free_events = []

    def __str__(self):
        if not self.events:
            return "No events in the calendar."
        events_str = '\n'.join(str(event) for event in self.events)
        return f"Calendar Events:\n{events_str}"

    def find_events_by_type(self, type: StEventType):
        return StCalendar(events=[event for event in self.events if event.event_type == type])
        

    def jsonify(self):
        json_data = []
        for e in self.events:
            json_data.append(e.jsonify())
        return json_data
    
stCalendar = StCalendar(events=get_events_from_calendar(calendar))
stCalendar.jsonify()
# Out:
# [{'type': 'Regular',
#   't_start': 1616623200.0,
#   't_end': 1616625000.0,
#   'summary': 'Writing Center Consultation Session for Tutorial'},
#  {'type': 'Regular',
#   't_start': 1642160400.0,
#   't_end': 1642161600.0,
#   'summary': '起床'},
#  {'type': 'Regular',
#   't_start': 1642162200.0,
#   't_end': 1642165200.0,
#   'summary': '坐车去东站'},
#  {'type': 'Regular',
#   't_start': 1642165800.0,
#   't_end': 1642169400.0,
#   'summary': '安检'},
#  {'type': 'Regular',
#   't_start': 1642169460.0,
#   't_end': 1642209600.0,
#   'summary': '坐车'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 2, 'date': 21},
#   't_end': {'year': 2022, 'month': 2, 'date': 22},
#   'summary': '第一周'},
#  {'type': 'Regular',
#   't_start': 1645373700.0,
#   't_end': 1645383600.0,
#   'summary': '材料结构与性能（全英文）'},
#  {'type': 'Regular',
#   't_start': 1645393800.0,
#   't_end': 1645403100.0,
#   'summary': '统计测试与回归（全英文）'},
#  {'type': 'Regular',
#   't_start': 1645413600.0,
#   't_end': 1645423800.0,
#   'summary': '毛泽东思想和中国特色社会主义理论体系概论'},
#  {'type': 'Regular',
#   't_start': 1645480200.0,
#   't_end': 1645493400.0,
#   'summary': '信息系统工程导论（全英文）'},
#  {'type': 'Regular',
#   't_start': 1645497000.0,
#   't_end': 1645509300.0,
#   'summary': '人文社科选修： 媒介素养（全英文）'},
#  {'type': 'Regular',
#   't_start': 1645546500.0,
#   't_end': 1645556400.0,
#   'summary': '人因工程学（全英文）'},
#  {'type': 'Regular',
#   't_start': 1645566600.0,
#   't_end': 1645575900.0,
#   'summary': '电路学（全英文）'},
#  {'type': 'Regular',
#   't_start': 1645640100.0,
#   't_end': 1645646100.0,
#   'summary': '体育-4'},
#  {'type': 'Regular',
#   't_start': 1645653000.0,
#   't_end': 1645666200.0,
#   'summary': '工科物理实验（全英文）'},
#  {'type': 'Regular',
#   't_start': 1645746000.0,
#   't_end': 1645748700.0,
#   'summary': '院系研讨会及形势与政策4（双语）'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 2, 'date': 28},
#   't_end': {'year': 2022, 'month': 3, 'date': 1},
#   'summary': '第二周'},
#  {'type': 'Regular',
#   't_start': 1646191200.0,
#   't_end': 1646201400.0,
#   'summary': '计算机辅助三维参数化设计'},
#  {'type': 'Regular',
#   't_start': 1646209800.0,
#   't_end': 1646209800.0,
#   'summary': '青年大学习'},
#  {'type': 'Regular',
#   't_start': 1646278200.0,
#   't_end': 1646288400.0,
#   'summary': '弦歌不辍：聆听音乐的多维魅力'},
#  {'type': 'Regular',
#   't_start': 1646389800.0,
#   't_end': 1646401800.0,
#   'summary': '货币金融学'},
#  {'type': 'Regular',
#   't_start': 1646440200.0,
#   't_end': 1646452500.0,
#   'summary': '政治经济学'},
#  {'type': 'Regular',
#   't_start': 1646460000.0,
#   't_end': 1646473500.0,
#   'summary': '财政学'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 3, 'date': 7},
#   't_end': {'year': 2022, 'month': 3, 'date': 8},
#   'summary': '第三周'},
#  {'type': 'Regular',
#   't_start': 1646955600.0,
#   't_end': 1646958300.0,
#   'summary': '院系研讨会及形势与政策4（双语）'},
#  {'type': 'Regular',
#   't_start': 1647131400.0,
#   't_end': 1647143400.0,
#   'summary': '会计学'},
#  {'type': 'Regular',
#   't_start': 1647151200.0,
#   't_end': 1647164700.0,
#   'summary': '统计学'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 3, 'date': 14},
#   't_end': {'year': 2022, 'month': 3, 'date': 15},
#   'summary': '第四周'},
#  {'type': 'Regular',
#   't_start': 1647274500.0,
#   't_end': 1647284400.0,
#   'summary': '内在的宇宙：探索心灵的奥秘'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 3, 'date': 21},
#   't_end': {'year': 2022, 'month': 3, 'date': 22},
#   'summary': '第五周'},
#  {'type': 'Regular',
#   't_start': 1648165200.0,
#   't_end': 1648167900.0,
#   'summary': '院系研讨会及形势与政策4（双语）'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 3, 'date': 28},
#   't_end': {'year': 2022, 'month': 3, 'date': 29},
#   'summary': '第六周'},
#  {'type': 'Regular',
#   't_start': 1648737000.0,
#   't_end': 1648738800.0,
#   'summary': '起床洗漱'},
#  {'type': 'Regular',
#   't_start': 1648738800.0,
#   't_end': 1648743000.0,
#   'summary': '地铁'},
#  {'type': 'Regular',
#   't_start': 1648743600.0,
#   't_end': 1648749000.0,
#   'summary': '安检'},
#  {'type': 'Regular',
#   't_start': 1648749600.0,
#   't_end': 1648766700.0,
#   'summary': 'MU9885'},
#  {'type': 'Regular',
#   't_start': 1648767600.0,
#   't_end': 1648776600.0,
#   'summary': '地铁'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 4, 'date': 4},
#   't_end': {'year': 2022, 'month': 4, 'date': 5},
#   'summary': '第七周'},
#  {'type': 'Regular',
#   't_start': 1649104200.0,
#   't_end': 1649107800.0,
#   'summary': '地铁'},
#  {'type': 'Regular',
#   't_start': 1649109600.0,
#   't_end': 1649113200.0,
#   'summary': '安检'},
#  {'type': 'Regular',
#   't_start': 1649115000.0,
#   't_end': 1649125800.0,
#   'summary': '乘坐MF8453 杭州萧山T3-成都天府T2 当地时间15:30-18:30［航旅纵横]'},
#  {'type': 'Regular',
#   't_start': 1649374800.0,
#   't_end': 1649377500.0,
#   'summary': '院系研讨会及形势与政策4（双语）'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 4, 'date': 11},
#   't_end': {'year': 2022, 'month': 4, 'date': 12},
#   'summary': '第八周'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 4, 'date': 18},
#   't_end': {'year': 2022, 'month': 4, 'date': 19},
#   'summary': '第九周'},
#  {'type': 'Regular',
#   't_start': 1650584400.0,
#   't_end': 1650587100.0,
#   'summary': '院系研讨会及形势与政策4（双语）'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 4, 'date': 25},
#   't_end': {'year': 2022, 'month': 4, 'date': 26},
#   'summary': '第十周'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 5, 'date': 2},
#   't_end': {'year': 2022, 'month': 5, 'date': 3},
#   'summary': '第十一周'},
#  {'type': 'Regular',
#   't_start': 1651794000.0,
#   't_end': 1651796700.0,
#   'summary': '院系研讨会及形势与政策4（双语）'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 5, 'date': 9},
#   't_end': {'year': 2022, 'month': 5, 'date': 10},
#   'summary': '第十二周'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 5, 'date': 16},
#   't_end': {'year': 2022, 'month': 5, 'date': 17},
#   'summary': '第十三周'},
#  {'type': 'Regular',
#   't_start': 1653003600.0,
#   't_end': 1653006300.0,
#   'summary': '院系研讨会及形势与政策4（双语）'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 5, 'date': 23},
#   't_end': {'year': 2022, 'month': 5, 'date': 24},
#   'summary': '第十四周'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 5, 'date': 30},
#   't_end': {'year': 2022, 'month': 5, 'date': 31},
#   'summary': '第十五周'},
#  {'type': 'Regular',
#   't_start': 1654213200.0,
#   't_end': 1654215900.0,
#   'summary': '院系研讨会及形势与政策4（双语）'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 6, 'date': 6},
#   't_end': {'year': 2022, 'month': 6, 'date': 7},
#   'summary': '第十六周'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 6, 'date': 9},
#   't_end': {'year': 2022, 'month': 6, 'date': 10},
#   'summary': '复习材料'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 6, 'date': 10},
#   't_end': {'year': 2022, 'month': 6, 'date': 11},
#   'summary': '复习材料'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 6, 'date': 13},
#   't_end': {'year': 2022, 'month': 6, 'date': 14},
#   'summary': '第十七周'},
#  {'type': 'Regular',
#   't_start': 1655355600.0,
#   't_end': 1655362800.0,
#   'summary': 'Final 材料'},
#  {'type': 'Regular',
#   't_start': 1655433000.0,
#   't_end': 1655440200.0,
#   'summary': 'Final 概统'},
#  {'type': 'Regular',
#   't_start': 1655654400.0,
#   't_end': 1655659800.0,
#   'summary': '背毛概'},
#  {'type': 'Regular',
#   't_start': 1655660700.0,
#   't_end': 1655666100.0,
#   'summary': '做电路例题'},
#  {'type': 'Regular',
#   't_start': 1655685000.0,
#   't_end': 1655692200.0,
#   'summary': 'Final 电路'},
#  {'type': 'Regular',
#   't_start': 1655778600.0,
#   't_end': 1655785800.0,
#   'summary': 'Final 概论'},
#  {'type': 'Regular',
#   't_start': 1655857800.0,
#   't_end': 1655865000.0,
#   'summary': 'Final 人因'},
#  {'type': 'Regular',
#   't_start': 1656359520.0,
#   't_end': 1656361800.0,
#   'summary': '接陈大佬'},
#  {'type': 'Regular',
#   't_start': 1656362100.0,
#   't_end': 1656367500.0,
#   'summary': '打车：火车南 -> 双龙洞（最少29min，最多40min）'},
#  {'type': 'Regular',
#   't_start': 1656368100.0,
#   't_end': 1656369900.0,
#   'summary': '双龙洞坐旅游车上山'},
#  {'type': 'Regular',
#   't_start': 1656369900.0,
#   't_end': 1656375300.0,
#   'summary': '在双龙洞耍'},
#  {'type': 'Regular',
#   't_start': 1656375300.0,
#   't_end': 1656377100.0,
#   'summary': '打车：双龙洞 -> 融景湾'},
#  {'type': 'Regular',
#   't_start': 1656377400.0,
#   't_end': 1656379200.0,
#   'summary': '骑/走到古子城'},
#  {'type': 'Regular',
#   't_start': 1656379800.0,
#   't_end': 1656387000.0,
#   'summary': '古子城干饭（古婺酒坊/V6/HoHo）'},
#  {'type': 'Regular',
#   't_start': 1656387000.0,
#   't_end': 1656392400.0,
#   'summary': '逛古子城和婺州公园'},
#  {'type': 'Regular',
#   't_start': 1656392400.0,
#   't_end': 1656396000.0,
#   'summary': '回融景湾'},
#  {'type': 'Regular',
#   't_start': 1656433800.0,
#   't_end': 1656437400.0,
#   'summary': '轻轨：万达广场 -> 秦塘'},
#  {'type': 'Regular',
#   't_start': 1656469320.0,
#   't_end': 1656478500.0,
#   'summary': '高铁：义乌 -> 温岭'},
#  {'type': 'Regular',
#   't_start': 1656638460.0,
#   't_end': 1656652200.0,
#   'summary': '高铁：临海 -> 南京南'},
#  {'type': 'Regular',
#   't_start': 1656653400.0,
#   't_end': 1656655200.0,
#   'summary': '南京南 -> 城中美家酒店'},
#  {'type': 'Regular',
#   't_start': 1657476000.0,
#   't_end': 1657490400.0,
#   'summary': 'Topology Lesson 4'},
#  {'type': 'Regular',
#   't_start': 1657492200.0,
#   't_end': 1657504800.0,
#   'summary': '2019-A'},
#  {'type': 'Regular',
#   't_start': 1657562400.0,
#   't_end': 1657576800.0,
#   'summary': 'Topology Lesson 5'},
#  {'type': 'Regular',
#   't_start': 1657578600.0,
#   't_end': 1657591200.0,
#   'summary': '2020-A Problem01'},
#  {'type': 'Regular',
#   't_start': 1657643400.0,
#   't_end': 1657656000.0,
#   'summary': '抽血'},
#  {'type': 'Regular',
#   't_start': 1657663200.0,
#   't_end': 1657677600.0,
#   'summary': 'Topology Lesson 6'},
#  {'type': 'Regular',
#   't_start': 1657728000.0,
#   't_end': 1657733400.0,
#   'summary': '拔掉智齿！'},
#  {'type': 'Regular',
#   't_start': 1657749600.0,
#   't_end': 1657764000.0,
#   'summary': 'Topology Lesson 7'},
#  {'type': 'Regular',
#   't_start': 1658595600.0,
#   't_end': 1658613600.0,
#   'summary': '2021-2022年度第三届全国大学生算法设计与编程挑战赛（夏季赛）'},
#  {'type': 'Regular',
#   't_start': 1658680200.0,
#   't_end': 1658685600.0,
#   'summary': 'Solidity C06 - 09'},
#  {'type': 'Regular',
#   't_start': 1658687400.0,
#   't_end': 1658692800.0,
#   'summary': 'Topology Lesson 05'},
#  {'type': 'Regular',
#   't_start': 1658696400.0,
#   't_end': 1658709000.0,
#   'summary': '建模'},
#  {'type': 'Regular',
#   't_start': 1658714400.0,
#   't_end': 1658719800.0,
#   'summary': 'Blender'},
#  {'type': 'Regular',
#   't_start': 1658766600.0,
#   't_end': 1658770200.0,
#   'summary': 'Solidity 13'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 8, 'date': 4},
#   't_end': {'year': 2022, 'month': 8, 'date': 8},
#   'summary': '2022年第三届“华数杯”全国大学生数学建模竞赛'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 9, 'date': 1},
#   't_end': {'year': 2022, 'month': 9, 'date': 2},
#   'summary': 'Birth'},
#  {'type': 'Regular',
#   't_start': 1662336900.0,
#   't_end': 1662346800.0,
#   'summary': '工程经济学分析'},
#  {'type': 'Regular',
#   't_start': 1662357000.0,
#   't_end': 1662366300.0,
#   'summary': '数据挖掘'},
#  {'type': 'Regular',
#   't_start': 1662377400.0,
#   't_end': 1662386700.0,
#   'summary': '现代企业物流'},
#  {'type': 'Regular',
#   't_start': 1662423300.0,
#   't_end': 1662433200.0,
#   'summary': '工程管理'},
#  {'type': 'Regular',
#   't_start': 1662509700.0,
#   't_end': 1662519600.0,
#   'summary': '运筹学'},
#  {'type': 'Regular',
#   't_start': 1662549600.0,
#   't_end': 1662558900.0,
#   'summary': '习近平新时代中国特色社会主义思想概论'},
#  {'type': 'Regular',
#   't_start': 1662636000.0,
#   't_end': 1662645300.0,
#   'summary': '诗歌导论'},
#  {'type': 'Regular',
#   't_start': 1662636000.0,
#   't_end': 1662645300.0,
#   'summary': '诗歌导论'},
#  {'type': 'Regular',
#   't_start': 1662682500.0,
#   't_end': 1662692400.0,
#   'summary': '制造工艺与分析'},
#  {'type': 'Regular',
#   't_start': 1662709200.0,
#   't_end': 1662711900.0,
#   'summary': '形策'},
#  {'type': 'Regular',
#   't_start': 1662742800.0,
#   't_end': 1662750000.0,
#   'summary': '政治经济学'},
#  {'type': 'Regular',
#   't_start': 1662769800.0,
#   't_end': 1662777000.0,
#   'summary': '财政学'},
#  {'type': 'Regular',
#   't_start': 1662829200.0,
#   't_end': 1662836400.0,
#   'summary': '会计学'},
#  {'type': 'Regular',
#   't_start': 1662847200.0,
#   't_end': 1662854400.0,
#   'summary': '统计学'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 9, 'date': 15},
#   't_end': {'year': 2022, 'month': 9, 'date': 19},
#   'summary': '建模国赛'},
#  {'type': 'Regular',
#   't_start': 1663653000.0,
#   't_end': 1663662300.0,
#   'summary': '微观经济'},
#  {'type': 'Regular',
#   't_start': 1665176400.0,
#   't_end': 1665198000.0,
#   'summary': '核酸-志愿者'},
#  {'type': 'Regular',
#   't_start': 1665228000.0,
#   't_end': 1665237300.0,
#   'summary': '诗歌导论'},
#  {'type': 'Regular',
#   't_start': 1665274500.0,
#   't_end': 1665284400.0,
#   'summary': '制造工艺与分析'},
#  {'type': 'Regular',
#   't_start': 1665301200.0,
#   't_end': 1665303900.0,
#   'summary': '形策'},
#  {'type': 'Regular',
#   't_start': 1665453600.0,
#   't_end': 1665457200.0,
#   'summary': 'TSA'},
#  {'type': 'Regular',
#   't_start': 1665535200.0,
#   't_end': 1665538800.0,
#   'summary': '实验'},
#  {'type': 'Regular',
#   't_start': 1665704400.0,
#   't_end': 1665707100.0,
#   'summary': '申学讲座'},
#  {'type': 'Regular',
#   't_start': 1665801000.0,
#   't_end': 1665808200.0,
#   'summary': 'Final 政治经济学'},
#  {'type': 'Regular',
#   't_start': 1665853200.0,
#   't_end': 1665860400.0,
#   'summary': 'Final 财政学'},
#  {'type': 'Regular',
#   't_start': 1665867600.0,
#   't_end': 1665874800.0,
#   'summary': 'Final 会计学'},
#  {'type': 'Regular',
#   't_start': 1665876600.0,
#   't_end': 1665883800.0,
#   'summary': 'Final 统计学'},
#  {'type': 'Regular',
#   't_start': 1666242000.0,
#   't_end': 1666249200.0,
#   'summary': '组会 PD早期筛查'},
#  {'type': 'Regular',
#   't_start': 1667512800.0,
#   't_end': 1667520000.0,
#   'summary': 'Mid 微观经济'},
#  {'type': 'Regular',
#   't_start': 1667530800.0,
#   't_end': 1667538000.0,
#   'summary': 'Mid 工程经济学'},
#  {'type': 'Regular',
#   't_start': 1667800200.0,
#   't_end': 1667809500.0,
#   'summary': 'Mid 数据挖掘'},
#  {'type': 'Regular',
#   't_start': 1668145800.0,
#   't_end': 1668155700.0,
#   'summary': 'Mid 制造工艺与分析'},
#  {'type': 'Regular',
#   't_start': 1668655800.0,
#   't_end': 1668661200.0,
#   'summary': '苏武牧羊'},
#  {'type': 'Regular',
#   't_start': 1668721800.0,
#   't_end': 1668729000.0,
#   'summary': 'Mid 运筹学'},
#  {'type': 'Regular',
#   't_start': 1668736800.0,
#   't_end': 1668744000.0,
#   'summary': 'Mid 概统监考'},
#  {'type': 'Regular',
#   't_start': 1668904200.0,
#   't_end': 1668911400.0,
#   'summary': 'Final 膝盖'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 11, 'date': 24},
#   't_end': {'year': 2022, 'month': 11, 'date': 25},
#   'summary': '亚太赛'},
#  {'type': 'Regular',
#   't_start': 1669288800.0,
#   't_end': 1669298100.0,
#   'summary': 'Final 诗歌导论'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 11, 'date': 25},
#   't_end': {'year': 2022, 'month': 11, 'date': 26},
#   'summary': '亚太赛'},
#  {'type': 'Regular',
#   't_start': 1669326600.0,
#   't_end': 1669333800.0,
#   'summary': 'Mid 制造'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 11, 'date': 26},
#   't_end': {'year': 2022, 'month': 11, 'date': 27},
#   'summary': '亚太赛'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 11, 'date': 27},
#   't_end': {'year': 2022, 'month': 11, 'date': 28},
#   'summary': '亚太赛'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 11, 'date': 28},
#   't_end': {'year': 2022, 'month': 11, 'date': 29},
#   'summary': '亚太赛'},
#  {'type': 'All day',
#   't_start': {'year': 2022, 'month': 12, 'date': 10},
#   't_end': {'year': 2022, 'month': 12, 'date': 11},
#   'summary': '预计 六级考试'},
#  {'type': 'Regular',
#   't_start': 1670881800.0,
#   't_end': 1670885400.0,
#   'summary': 'meeting with Liz'},
#  {'type': 'Regular',
#   't_start': 1671215400.0,
#   't_end': 1671222600.0,
#   'summary': '团校学习'},
#  {'type': 'Regular',
#   't_start': 1671899400.0,
#   't_end': 1671906600.0,
#   'summary': 'Final 工程经济学'},
#  {'type': 'Regular',
#   't_start': 1671987600.0,
#   't_end': 1671994800.0,
#   'summary': 'Final 概统 监考'},
#  {'type': 'Regular',
#   't_start': 1672033800.0,
#   't_end': 1672043100.0,
#   'summary': 'Final 数据挖掘'},
#  {'type': 'Regular',
#   't_start': 1672192800.0,
#   't_end': 1672200000.0,
#   'summary': 'Final 制造'},
#  {'type': 'Regular',
#   't_start': 1673906400.0,
#   't_end': 1673910000.0,
#   'summary': 'JHFLSSCU'},
#  {'type': 'All day',
#   't_start': {'year': 2023, 'month': 1, 'date': 22},
#   't_end': {'year': 2023, 'month': 1, 'date': 23},
#   'summary': '拜年'},
#  {'type': 'All day',
#   't_start': {'year': 2023, 'month': 1, 'date': 23},
#   't_end': {'year': 2023, 'month': 1, 'date': 24},
#   'summary': 'S6&7'},
#  {'type': 'Regular',
#   't_start': 1674424800.0,
#   't_end': 1674428400.0,
#   'summary': '流浪地球'},
#  {'type': 'Regular',
#   't_start': 1676058600.0,
#   't_end': 1676069700.0,
#   'summary': '杭州 -> 成都'},
#  {'type': 'Regular',
#   't_start': 1699117200.0,
#   't_end': 1699124400.0,
#   'summary': 'Research Design'},
#  {'type': 'Regular',
#   't_start': 1699131600.0,
#   't_end': 1699146000.0,
#   'summary': '写周报'},
#  {'type': 'Regular',
#   't_start': 1699223400.0,
#   't_end': 1699224300.0,
#   'summary': 'AirBus Intern 面试'},
#  {'type': 'Regular',
#   't_start': 1699853400.0,
#   't_end': 1699862400.0,
#   'summary': '同济 组会'},
#  {'type': 'Regular',
#   't_start': 1699912800.0,
#   't_end': 1699914600.0,
#   'summary': 'AIRBUS Interview Invitation - XU Ke'},
#  {'type': 'Regular',
#   't_start': 1699912800.0,
#   't_end': 1699914600.0,
#   'summary': '空客面试'},
#  {'type': 'Regular',
#   't_start': 1700182800.0,
#   't_end': 1700186400.0,
#   'summary': '京东研学活动'},
#  {'type': 'Regular',
#   't_start': 1700240400.0,
#   't_end': 1700269200.0,
#   'summary': '党校'},
#  {'type': 'Regular',
#   't_start': 1700672400.0,
#   't_end': 1700679600.0,
#   'summary': '办理银行卡'},
#  {'type': 'Regular',
#   't_start': 1701063000.0,
#   't_end': 1701072000.0,
#   'summary': '同济 组会'},
#  {'type': 'All day',
#   't_start': {'year': 2023, 'month': 12, 'date': 7},
#   't_end': {'year': 2023, 'month': 12, 'date': 8},
#   'summary': '交思想汇报'},
#  {'type': 'Regular',
#   't_start': 1701966000.0,
#   't_end': 1701973500.0,
#   'summary': 'ZLY'},
#  {'type': 'Regular',
#   't_start': 1701982800.0,
#   't_end': 1701986400.0,
#   'summary': '党员大会'},
#  {'type': 'Regular',
#   't_start': 1702004400.0,
#   't_end': 1702008000.0,
#   'summary': 'Senior design EHR Xuke'},
#  {'type': 'Regular',
#   't_start': 1702076400.0,
#   't_end': 1702080000.0,
#   'summary': '讨论 Supply Chain'},
#  {'type': 'Regular',
#   't_start': 1703170500.0,
#   't_end': 1703180400.0,
#   'summary': '双流 - 萧山 CA4519 NJY'},
#  {'type': 'Regular',
#   't_start': 1703260200.0,
#   't_end': 1703270100.0,
#   'summary': '双流 - 萧山 EU2259'},
#  {'type': 'Regular',
#   't_start': 1703386980.0,
#   't_end': 1703389320.0,
#   'summary': '杭州南 - 金华 G1641'},
#  {'type': 'Regular',
#   't_start': 1703388000.0,
#   't_end': 1703400900.0,
#   'summary': '萧山 - 双流 EU2260 NJY'},
#  {'type': 'Regular',
#   't_start': 1704036000.0,
#   't_end': 1704047100.0,
#   'summary': '义乌 - 天府 CZ2051'},
#  {'type': 'Regular',
#   't_start': 1704673200.0,
#   't_end': 1704674400.0,
#   'summary': '毕设 中期答辩'},
#  {'type': 'Regular',
#   't_start': 1704834000.0,
#   't_end': 1704843600.0,
#   'summary': '成都东 - 重庆北 D50'},
#  {'type': 'Regular',
#   't_start': 1704988800.0,
#   't_end': 1704997500.0,
#   'summary': '重庆 - 北京 HU7568'},
#  {'type': 'Regular',
#   't_start': 1704990000.0,
#   't_end': 1704999900.0,
#   'summary': '重庆- 沈阳 3U8037'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 1, 'date': 15},
#   't_end': {'year': 2024, 'month': 1, 'date': 16},
#   'summary': '入职 Airbus (Week 1)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 1, 'date': 16},
#   't_end': {'year': 2024, 'month': 1, 'date': 17},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 1, 'date': 17},
#   't_end': {'year': 2024, 'month': 1, 'date': 18},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 1, 'date': 18},
#   't_end': {'year': 2024, 'month': 1, 'date': 19},
#   'summary': 'Workday at Airbus'},
#  {'type': 'Regular',
#   't_start': 1705599000.0,
#   't_end': 1705609800.0,
#   'summary': '周老师小组会议'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 1, 'date': 22},
#   't_end': {'year': 2024, 'month': 1, 'date': 23},
#   'summary': 'Workday at Airbus (Week 2)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 1, 'date': 23},
#   't_end': {'year': 2024, 'month': 1, 'date': 24},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 1, 'date': 24},
#   't_end': {'year': 2024, 'month': 1, 'date': 25},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 1, 'date': 25},
#   't_end': {'year': 2024, 'month': 1, 'date': 26},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 1, 'date': 26},
#   't_end': {'year': 2024, 'month': 1, 'date': 27},
#   'summary': 'Workday at Airbus'},
#  {'type': 'Regular',
#   't_start': 1706245800.0,
#   't_end': 1706248320.0,
#   'summary': '北京南- 天津西C2'},
#  {'type': 'Regular',
#   't_start': 1706408640.0,
#   't_end': 1706410620.0,
#   'summary': '天津 - 北京南 C2590'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 1, 'date': 29},
#   't_end': {'year': 2024, 'month': 1, 'date': 30},
#   'summary': 'Workday at Airbus (Week 3)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 1, 'date': 30},
#   't_end': {'year': 2024, 'month': 1, 'date': 31},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 1, 'date': 31},
#   't_end': {'year': 2024, 'month': 2, 'date': 1},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 2, 'date': 1},
#   't_end': {'year': 2024, 'month': 2, 'date': 2},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 2, 'date': 2},
#   't_end': {'year': 2024, 'month': 2, 'date': 3},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 2, 'date': 5},
#   't_end': {'year': 2024, 'month': 2, 'date': 6},
#   'summary': 'Workday at Airbus (Week 4)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 2, 'date': 6},
#   't_end': {'year': 2024, 'month': 2, 'date': 7},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 2, 'date': 6},
#   't_end': {'year': 2024, 'month': 2, 'date': 7},
#   'summary': '12306 买 21 号的票'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 2, 'date': 7},
#   't_end': {'year': 2024, 'month': 2, 'date': 8},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 2, 'date': 8},
#   't_end': {'year': 2024, 'month': 2, 'date': 9},
#   'summary': 'Workday at Airbus 生病没去'},
#  {'type': 'Regular',
#   't_start': 1707428700.0,
#   't_end': 1707437400.0,
#   'summary': '北京大兴 - 义乌 CZ8960'},
#  {'type': 'Regular',
#   't_start': 1707753600.0,
#   't_end': 1707764400.0,
#   'summary': '金华 - 荣小馆 临海世纪花城店'},
#  {'type': 'Regular',
#   't_start': 1707764400.0,
#   't_end': 1707773400.0,
#   'summary': '用餐'},
#  {'type': 'Regular',
#   't_start': 1707773400.0,
#   't_end': 1707775200.0,
#   'summary': '荣小馆 - 紫阳古街'},
#  {'type': 'Regular',
#   't_start': 1707775200.0,
#   't_end': 1707782400.0,
#   'summary': '游玩'},
#  {'type': 'Regular',
#   't_start': 1707781800.0,
#   't_end': 1707786000.0,
#   'summary': '紫阳古街 - 和合大院 东海大道店'},
#  {'type': 'Regular',
#   't_start': 1707786000.0,
#   't_end': 1707793200.0,
#   'summary': '用餐'},
#  {'type': 'Regular',
#   't_start': 1707793200.0,
#   't_end': 1707800400.0,
#   'summary': '游玩 :)处于台州市区'},
#  {'type': 'Regular',
#   't_start': 1707841800.0,
#   't_end': 1707849000.0,
#   'summary': '酒店 - 天台山景区'},
#  {'type': 'Regular',
#   't_start': 1707849000.0,
#   't_end': 1707859800.0,
#   'summary': '游玩'},
#  {'type': 'Regular',
#   't_start': 1707859800.0,
#   't_end': 1707868800.0,
#   'summary': '天台山景区- 金华'},
#  {'type': 'Regular',
#   't_start': 1708185480.0,
#   't_end': 1708202520.0,
#   'summary': '金华站 - 上海南站 K808'},
#  {'type': 'Regular',
#   't_start': 1708225200.0,
#   't_end': 1708228800.0,
#   'summary': '上海南站 - 浦东机场'},
#  {'type': 'Regular',
#   't_start': 1708235700.0,
#   't_end': 1708245300.0,
#   'summary': '上海浦东 - 沈阳桃仙 MF1211 CZ6508'},
#  {'type': 'Regular',
#   't_start': 1708547640.0,
#   't_end': 1708557540.0,
#   'summary': '沈阳 - 北京朝阳 G922'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 2, 'date': 23},
#   't_end': {'year': 2024, 'month': 2, 'date': 24},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 2, 'date': 26},
#   't_end': {'year': 2024, 'month': 2, 'date': 27},
#   'summary': 'Workday at Airbus (Week 6)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 2, 'date': 27},
#   't_end': {'year': 2024, 'month': 2, 'date': 28},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 2, 'date': 28},
#   't_end': {'year': 2024, 'month': 2, 'date': 29},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 2, 'date': 29},
#   't_end': {'year': 2024, 'month': 3, 'date': 1},
#   'summary': 'Workday at Airbus'},
#  {'type': 'Regular',
#   't_start': 1709137800.0,
#   't_end': 1709170200.0,
#   'summary': '2024 Airbus in China All-Staff Symposium'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 1},
#   't_end': {'year': 2024, 'month': 3, 'date': 2},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 2},
#   't_end': {'year': 2024, 'month': 3, 'date': 3},
#   'summary': '个人所得税App 退税'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 4},
#   't_end': {'year': 2024, 'month': 3, 'date': 5},
#   'summary': 'Workday at Airbus (Week 7)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 5},
#   't_end': {'year': 2024, 'month': 3, 'date': 6},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 6},
#   't_end': {'year': 2024, 'month': 3, 'date': 7},
#   'summary': 'Workday at Airbus'},
#  {'type': 'Regular',
#   't_start': 1709726400.0,
#   't_end': 1709730000.0,
#   'summary': 'Senior design - IBD 组会'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 7},
#   't_end': {'year': 2024, 'month': 3, 'date': 8},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 8},
#   't_end': {'year': 2024, 'month': 3, 'date': 9},
#   'summary': 'Workday at Airbus - Half Day'},
#  {'type': 'Regular',
#   't_start': 1709850600.0,
#   't_end': 1709860560.0,
#   'summary': '沈阳 - 北京朝阳 G924 NJY'},
#  {'type': 'Regular',
#   't_start': 1709857800.0,
#   't_end': 1709863200.0,
#   'summary': '顺义 - 北京朝阳'},
#  {'type': 'Regular',
#   't_start': 1709875800.0,
#   't_end': 1709886600.0,
#   'summary': '同济 组会'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 10},
#   't_end': {'year': 2024, 'month': 3, 'date': 11},
#   'summary': 'SCU (Week 3)'},
#  {'type': 'Regular',
#   't_start': 1710029100.0,
#   't_end': 1710038940.0,
#   'summary': '北京朝阳 - 沈阳 G927 NJY'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 11},
#   't_end': {'year': 2024, 'month': 3, 'date': 12},
#   'summary': 'Workday at Airbus (Week 8)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 12},
#   't_end': {'year': 2024, 'month': 3, 'date': 13},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 13},
#   't_end': {'year': 2024, 'month': 3, 'date': 14},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 14},
#   't_end': {'year': 2024, 'month': 3, 'date': 15},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 15},
#   't_end': {'year': 2024, 'month': 3, 'date': 16},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 17},
#   't_end': {'year': 2024, 'month': 3, 'date': 18},
#   'summary': 'SCU (Week 4)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 18},
#   't_end': {'year': 2024, 'month': 3, 'date': 19},
#   'summary': 'Workday at Airbus (Week 9)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 19},
#   't_end': {'year': 2024, 'month': 3, 'date': 20},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 19},
#   't_end': {'year': 2024, 'month': 3, 'date': 20},
#   'summary': '体测集中测试 - 开始'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 20},
#   't_end': {'year': 2024, 'month': 3, 'date': 21},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 21},
#   't_end': {'year': 2024, 'month': 3, 'date': 22},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 22},
#   't_end': {'year': 2024, 'month': 3, 'date': 23},
#   'summary': 'Workday at Airbus - Half day'},
#  {'type': 'Regular',
#   't_start': 1711135980.0,
#   't_end': 1711141140.0,
#   'summary': '北京丰台 - 天津 T57'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 24},
#   't_end': {'year': 2024, 'month': 3, 'date': 25},
#   'summary': 'SCU (Week 5)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 25},
#   't_end': {'year': 2024, 'month': 3, 'date': 26},
#   'summary': 'Workday at Airbus (10)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 26},
#   't_end': {'year': 2024, 'month': 3, 'date': 27},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 27},
#   't_end': {'year': 2024, 'month': 3, 'date': 28},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 28},
#   't_end': {'year': 2024, 'month': 3, 'date': 29},
#   'summary': 'Workday at Airbus'},
#  {'type': 'Regular',
#   't_start': 1711573200.0,
#   't_end': 1711576800.0,
#   'summary': 'GitHub intro by Xu Ke'},
#  {'type': 'Regular',
#   't_start': 1711584000.0,
#   't_end': 1711587600.0,
#   'summary': 'Regular meeting'},
#  {'type': 'Regular',
#   't_start': 1711605600.0,
#   't_end': 1711609140.0,
#   'summary': 'IEA 2024 - Proposal Submission'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 29},
#   't_end': {'year': 2024, 'month': 3, 'date': 30},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 3, 'date': 31},
#   't_end': {'year': 2024, 'month': 4, 'date': 1},
#   'summary': 'SCU (Week 6)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 1},
#   't_end': {'year': 2024, 'month': 4, 'date': 2},
#   'summary': 'Workday at Airbus (Week 11)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 2},
#   't_end': {'year': 2024, 'month': 4, 'date': 3},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 3},
#   't_end': {'year': 2024, 'month': 4, 'date': 4},
#   'summary': 'Workday at Airbus'},
#  {'type': 'Regular',
#   't_start': 1712185440.0,
#   't_end': 1712196660.0,
#   'summary': '北京南 - 青岛北 G209'},
#  {'type': 'Regular',
#   't_start': 1712295000.0,
#   't_end': 1712305800.0,
#   'summary': '同济 组会'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 7},
#   't_end': {'year': 2024, 'month': 4, 'date': 8},
#   'summary': 'SCU (Week 7)'},
#  {'type': 'Regular',
#   't_start': 1712428200.0,
#   't_end': 1712440680.0,
#   'summary': '青岛北 - 北京南 G206'},
#  {'type': 'Regular',
#   't_start': 1712467800.0,
#   't_end': 1712478600.0,
#   'summary': '同济 组会'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 8},
#   't_end': {'year': 2024, 'month': 4, 'date': 9},
#   'summary': 'Workday at Airbus (Week 12)'},
#  {'type': 'Regular',
#   't_start': 1712700000.0,
#   't_end': 1712703600.0,
#   'summary': '和鲸社区讨论'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 11},
#   't_end': {'year': 2024, 'month': 4, 'date': 12},
#   'summary': 'Workday at Airbus'},
#  {'type': 'Regular',
#   't_start': 1712807100.0,
#   't_end': 1712808000.0,
#   'summary': 'Meeting with Vincent'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 12},
#   't_end': {'year': 2024, 'month': 4, 'date': 13},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 14},
#   't_end': {'year': 2024, 'month': 4, 'date': 15},
#   'summary': 'SCU (Week 8)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 15},
#   't_end': {'year': 2024, 'month': 4, 'date': 16},
#   'summary': 'Workday at Airbus (Week 13)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 16},
#   't_end': {'year': 2024, 'month': 4, 'date': 17},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 17},
#   't_end': {'year': 2024, 'month': 4, 'date': 18},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 18},
#   't_end': {'year': 2024, 'month': 4, 'date': 19},
#   'summary': 'Workday at Airbus'},
#  {'type': 'Regular',
#   't_start': 1713441600.0,
#   't_end': 1713445200.0,
#   'summary': 'Senior design - IBD 组会'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 19},
#   't_end': {'year': 2024, 'month': 4, 'date': 20},
#   'summary': 'Workday at Airbus - Half day'},
#  {'type': 'Regular',
#   't_start': 1713585600.0,
#   't_end': 1713589200.0,
#   'summary': '李荣浩演唱会'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 21},
#   't_end': {'year': 2024, 'month': 4, 'date': 22},
#   'summary': 'SCU (Week 9)'},
#  {'type': 'Regular',
#   't_start': 1713763800.0,
#   't_end': 1713773700.0,
#   'summary': '北京大兴 - 成都双流 MU6649'},
#  {'type': 'Regular',
#   't_start': 1713896100.0,
#   't_end': 1713902400.0,
#   'summary': '体质测试 - 江安校区上午场'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 26},
#   't_end': {'year': 2024, 'month': 4, 'date': 27},
#   'summary': '体测集中测试 - 结束'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 28},
#   't_end': {'year': 2024, 'month': 4, 'date': 29},
#   'summary': 'SCU (Week 10)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 28},
#   't_end': {'year': 2024, 'month': 4, 'date': 29},
#   'summary': 'Senior design - Submission of the first draft of project reports'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 29},
#   't_end': {'year': 2024, 'month': 4, 'date': 30},
#   'summary': '体测毕业年级补测'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 4, 'date': 29},
#   't_end': {'year': 2024, 'month': 5, 'date': 1},
#   'summary': '体测毕业年级补测'},
#  {'type': 'Regular',
#   't_start': 1714620600.0,
#   't_end': 1714630800.0,
#   'summary': '成都天府 T2 - 北京首都 T2 HU7448'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 5, 'date': 5},
#   't_end': {'year': 2024, 'month': 5, 'date': 6},
#   'summary': 'SCU (Week 11)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 5, 'date': 6},
#   't_end': {'year': 2024, 'month': 5, 'date': 7},
#   'summary': 'Workday at Airbus (Week 16)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 5, 'date': 7},
#   't_end': {'year': 2024, 'month': 5, 'date': 8},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 5, 'date': 8},
#   't_end': {'year': 2024, 'month': 5, 'date': 9},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 5, 'date': 9},
#   't_end': {'year': 2024, 'month': 5, 'date': 10},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 5, 'date': 10},
#   't_end': {'year': 2024, 'month': 5, 'date': 11},
#   'summary': 'Workday at Airbus'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 5, 'date': 12},
#   't_end': {'year': 2024, 'month': 5, 'date': 13},
#   'summary': 'SCU (Week 12)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 5, 'date': 12},
#   't_end': {'year': 2024, 'month': 5, 'date': 13},
#   'summary': 'Senior design - Submission of the final report and plagiarism examinations. '},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 5, 'date': 13},
#   't_end': {'year': 2024, 'month': 5, 'date': 14},
#   'summary': 'Workday at Airbus (Week 17)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 5, 'date': 14},
#   't_end': {'year': 2024, 'month': 5, 'date': 15},
#   'summary': 'Workday at Airbus'},
#  {'type': 'Regular',
#   't_start': 1715743200.0,
#   't_end': 1715754300.0,
#   'summary': '北京大兴 - 成都天府 MU6659'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 5, 'date': 17},
#   't_end': {'year': 2024, 'month': 5, 'date': 18},
#   'summary': 'Senior design - Poster presentation'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 5, 'date': 19},
#   't_end': {'year': 2024, 'month': 5, 'date': 20},
#   'summary': 'SCU (Week 13)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 5, 'date': 19},
#   't_end': {'year': 2024, 'month': 5, 'date': 20},
#   'summary': '体测常规测试 - 结束'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 5, 'date': 26},
#   't_end': {'year': 2024, 'month': 5, 'date': 27},
#   'summary': 'SCU (Week 14)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 5, 'date': 26},
#   't_end': {'year': 2024, 'month': 5, 'date': 27},
#   'summary': 'Senior design - Final defenses'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 6, 'date': 1},
#   't_end': {'year': 2024, 'month': 6, 'date': 2},
#   'summary': '成都 - 义乌 待定'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 6, 'date': 2},
#   't_end': {'year': 2024, 'month': 6, 'date': 3},
#   'summary': 'SCU (Week 15)'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 6, 'date': 2},
#   't_end': {'year': 2024, 'month': 6, 'date': 3},
#   'summary': 'Senior design - Grades submission'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 6, 'date': 9},
#   't_end': {'year': 2024, 'month': 6, 'date': 10},
#   'summary': '毕业典礼'},
#  {'type': 'All day',
#   't_start': {'year': 2024, 'month': 6, 'date': 9},
#   't_end': {'year': 2024, 'month': 6, 'date': 10},
#   'summary': '义乌 - 成都 待定'}]
